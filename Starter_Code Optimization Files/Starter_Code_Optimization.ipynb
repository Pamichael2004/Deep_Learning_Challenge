# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
filtered_df = application_df.drop(columns=["EIN", "NAME"])
filtered_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
filtered_cat = filtered_df.dtypes[filtered_df.dtypes == "object"].index.tolist()
filtered_cat
# Out:
# ['APPLICATION_TYPE',
#  'AFFILIATION',
#  'CLASSIFICATION',
#  'USE_CASE',
#  'ORGANIZATION',
#  'INCOME_AMT',
#  'SPECIAL_CONSIDERATIONS']

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
app_type = filtered_df['APPLICATION_TYPE'].value_counts().reset_index()
app_type
# Out:
#    index  APPLICATION_TYPE
# 0     T3             27037
# 1     T4              1542
# 2     T6              1216
# 3     T5              1173
# 4    T19              1065
# 5     T8               737
# 6     T7               725
# 7    T10               528
# 8     T9               156
# 9    T13                66
# 10   T12                27
# 11    T2                16
# 12   T25                 3
# 13   T14                 3
# 14   T29                 2
# 15   T15                 2
# 16   T17                 1

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = []
application_types_to_replace = app_type[app_type['APPLICATION_TYPE'] <= 156]['index']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
class_count = filtered_df['CLASSIFICATION'].value_counts().reset_index()
class_count
# Out:
#     index  CLASSIFICATION
# 0   C1000           17326
# 1   C2000            6074
# 2   C1200            4837
# 3   C3000            1918
# 4   C2100            1883
# ..    ...             ...
# 66  C4120               1
# 67  C8210               1
# 68  C2561               1
# 69  C4500               1
# 70  C2150               1
#
# [71 rows x 2 columns]

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
class_count_filtered = []
class_count_filtered = class_count[class_count['CLASSIFICATION'] > 1]
class_count_filtered
# Out:
#     index  CLASSIFICATION
# 0   C1000           17326
# 1   C2000            6074
# 2   C1200            4837
# 3   C3000            1918
# 4   C2100            1883
# 5   C7000             777
# 6   C1700             287
# 7   C4000             194
# 8   C5000             116
# 9   C1270             114
# 10  C2700             104
# 11  C2800              95
# 12  C7100              75
# 13  C1300              58
# 14  C1280              50
# 15  C1230              36
# 16  C1400              34
# 17  C7200              32
# 18  C2300              32
# 19  C1240              30
# 20  C8000              20
# 21  C7120              18
# 22  C1500              16
# 23  C1800              15
# 24  C6000              15
# 25  C1250              14
# 26  C8200              11
# 27  C1238              10
# 28  C1278              10
# 29  C1235               9
# 30  C1237               9
# 31  C7210               7
# 32  C2400               6
# 33  C1720               6
# 34  C4100               6
# 35  C1257               5
# 36  C1600               5
# 37  C1260               3
# 38  C2710               3
# 39     C0               3
# 40  C3200               2
# 41  C1234               2
# 42  C1246               2
# 43  C1267               2
# 44  C1256               2

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = []
classifications_to_replace = class_count[class_count['CLASSIFICATION'] < 1883]['index']
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
filtered_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
numerical_df = pd.get_dummies(filtered_df)
numerical_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  \
# 0           1      5000              1                     1
# 1           1    108590              1                     0
# 2           1      5000              0                     0
# 3           1      6692              1                     0
# 4           1    142590              1                     0
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                     0
# 34295       1      5000              0                     0
# 34296       1      5000              0                     0
# 34297       1      5000              1                     0
# 34298       1  36500179              0                     0
#
#        APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     0
# 34297                     0                     0                     0
# 34298                     0                     0                     0
#
#        APPLICATION_TYPE_T15  APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  \
# 0                         0                     0                     0  ...
# 1                         0                     0                     0  ...
# 2                         0                     0                     0  ...
# 3                         0                     0                     0  ...
# 4                         0                     0                     0  ...
# ...                     ...                   ...                   ...  ...
# 34294                     0                     0                     0  ...
# 34295                     0                     0                     0  ...
# 34296                     0                     0                     0  ...
# 34297                     0                     0                     0  ...
# 34298                     0                     0                     0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 117 columns]

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y = numerical_df["IS_SUCCESSFUL"].values
X = numerical_df.drop(["IS_SUCCESSFUL"],1).values
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# <ipython-input-12-889307ec8b0c>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = numerical_df.drop(["IS_SUCCESSFUL"],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=120,
        step=5), activation=activation, input_dim=43))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 5)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=120,
            step=5),
            activation=activation))

    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

    return nn_model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  200
hidden_nodes_layer2 = 150
nn = tf.keras.models.Sequential()
nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="LeakyReLU")
)
# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="LeakyReLU"))
# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 200)               23400
#
#  dense_7 (Dense)             (None, 150)               30150
#
#  dense_8 (Dense)             (None, 1)                 151
#
# =================================================================
# Total params: 53,701
# Trainable params: 53,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled,y_train,epochs=300)
# Out:
# Epoch 1/300
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5844 - accuracy: 0.7198
# Epoch 2/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5596 - accuracy: 0.7278
# Epoch 3/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5544 - accuracy: 0.7294
# Epoch 4/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5532 - accuracy: 0.7294
# Epoch 5/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5513 - accuracy: 0.7310
# Epoch 6/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7308
# Epoch 7/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5502 - accuracy: 0.7311
# Epoch 8/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5490 - accuracy: 0.7303
# Epoch 9/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5485 - accuracy: 0.7310
# Epoch 10/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5479 - accuracy: 0.7316
# Epoch 11/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5474 - accuracy: 0.7307
# Epoch 12/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5473 - accuracy: 0.7322
# Epoch 13/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5459 - accuracy: 0.7336
# Epoch 14/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5463 - accuracy: 0.7328
# Epoch 15/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5452 - accuracy: 0.7332
# Epoch 16/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5453 - accuracy: 0.7324
# Epoch 17/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5453 - accuracy: 0.7318
# Epoch 18/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5449 - accuracy: 0.7330
# Epoch 19/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5443 - accuracy: 0.7330
# Epoch 20/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5441 - accuracy: 0.7341
# Epoch 21/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5433 - accuracy: 0.7340
# Epoch 22/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7327
# Epoch 23/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5438 - accuracy: 0.7343
# Epoch 24/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5439 - accuracy: 0.7346
# Epoch 25/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5437 - accuracy: 0.7328
# Epoch 26/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5430 - accuracy: 0.7343
# Epoch 27/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7339
# Epoch 28/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7338
# Epoch 29/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5424 - accuracy: 0.7351
# Epoch 30/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7324
# Epoch 31/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7353
# Epoch 32/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7334
# Epoch 33/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5422 - accuracy: 0.7352
# Epoch 34/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7341
# Epoch 35/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5412 - accuracy: 0.7346
# Epoch 36/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5419 - accuracy: 0.7347
# Epoch 37/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5409 - accuracy: 0.7352
# Epoch 38/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5415 - accuracy: 0.7350
# Epoch 39/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5410 - accuracy: 0.7358
# Epoch 40/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5409 - accuracy: 0.7352
# Epoch 41/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5408 - accuracy: 0.7355
# Epoch 42/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5405 - accuracy: 0.7353
# Epoch 43/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5401 - accuracy: 0.7351
# Epoch 44/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5406 - accuracy: 0.7347
# Epoch 45/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5395 - accuracy: 0.7348
# Epoch 46/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5406 - accuracy: 0.7359
# Epoch 47/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5401 - accuracy: 0.7358
# Epoch 48/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5398 - accuracy: 0.7362
# Epoch 49/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7346
# Epoch 50/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5399 - accuracy: 0.7353
# Epoch 51/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5392 - accuracy: 0.7351
# Epoch 52/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5518 - accuracy: 0.7349
# Epoch 53/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5399 - accuracy: 0.7359
# Epoch 54/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5413 - accuracy: 0.7371
# Epoch 55/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5385 - accuracy: 0.7368
# Epoch 56/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5386 - accuracy: 0.7370
# Epoch 57/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5387 - accuracy: 0.7371
# Epoch 58/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7371
# Epoch 59/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5386 - accuracy: 0.7355
# Epoch 60/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5386 - accuracy: 0.7365
# Epoch 61/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7364
# Epoch 62/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5385 - accuracy: 0.7360
# Epoch 63/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5389 - accuracy: 0.7373
# Epoch 64/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5382 - accuracy: 0.7366
# Epoch 65/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7363
# Epoch 66/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5383 - accuracy: 0.7371
# Epoch 67/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5382 - accuracy: 0.7373
# Epoch 68/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5391 - accuracy: 0.7372
# Epoch 69/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5385 - accuracy: 0.7367
# Epoch 70/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5378 - accuracy: 0.7361
# Epoch 71/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5382 - accuracy: 0.7361
# Epoch 72/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5378 - accuracy: 0.7394
# Epoch 73/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5377 - accuracy: 0.7372
# Epoch 74/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5375 - accuracy: 0.7360
# Epoch 75/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5379 - accuracy: 0.7376
# Epoch 76/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5381 - accuracy: 0.7375
# Epoch 77/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7373
# Epoch 78/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5377 - accuracy: 0.7373
# Epoch 79/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5374 - accuracy: 0.7380
# Epoch 80/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5379 - accuracy: 0.7379
# Epoch 81/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5377 - accuracy: 0.7372
# Epoch 82/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5377 - accuracy: 0.7383
# Epoch 83/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5374 - accuracy: 0.7373
# Epoch 84/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5378 - accuracy: 0.7364
# Epoch 85/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5367 - accuracy: 0.7367
# Epoch 86/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7376
# Epoch 87/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5373 - accuracy: 0.7372
# Epoch 88/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7385
# Epoch 89/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7372
# Epoch 90/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7372
# Epoch 91/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5370 - accuracy: 0.7375
# Epoch 92/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5370 - accuracy: 0.7371
# Epoch 93/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7384
# Epoch 94/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7384
# Epoch 95/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7381
# Epoch 96/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7377
# Epoch 97/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5368 - accuracy: 0.7369
# Epoch 98/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7397
# Epoch 99/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5364 - accuracy: 0.7360
# Epoch 100/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5372 - accuracy: 0.7374
# Epoch 101/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5364 - accuracy: 0.7372
# Epoch 102/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5364 - accuracy: 0.7386
# Epoch 103/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7358
# Epoch 104/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7380
# Epoch 105/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7378
# Epoch 106/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5360 - accuracy: 0.7379
# Epoch 107/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5359 - accuracy: 0.7379
# Epoch 108/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5355 - accuracy: 0.7378
# Epoch 109/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5368 - accuracy: 0.7373
# Epoch 110/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7387
# Epoch 111/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5357 - accuracy: 0.7383
# Epoch 112/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5357 - accuracy: 0.7391
# Epoch 113/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5361 - accuracy: 0.7374
# Epoch 114/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7385
# Epoch 115/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5356 - accuracy: 0.7392
# Epoch 116/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5364 - accuracy: 0.7378
# Epoch 117/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5355 - accuracy: 0.7380
# Epoch 118/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5353 - accuracy: 0.7381
# Epoch 119/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5359 - accuracy: 0.7381
# Epoch 120/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5353 - accuracy: 0.7400
# Epoch 121/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5351 - accuracy: 0.7381
# Epoch 122/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5350 - accuracy: 0.7394
# Epoch 123/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7389
# Epoch 124/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5357 - accuracy: 0.7370
# Epoch 125/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5384 - accuracy: 0.7380
# Epoch 126/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5446 - accuracy: 0.7374
# Epoch 127/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5340 - accuracy: 0.7404
# Epoch 128/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7398
# Epoch 129/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5345 - accuracy: 0.7392
# Epoch 130/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5344 - accuracy: 0.7383
# Epoch 131/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5346 - accuracy: 0.7397
# Epoch 132/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7393
# Epoch 133/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5345 - accuracy: 0.7396
# Epoch 134/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5352 - accuracy: 0.7407
# Epoch 135/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5351 - accuracy: 0.7379
# Epoch 136/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5349 - accuracy: 0.7407
# Epoch 137/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5349 - accuracy: 0.7399
# Epoch 138/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5349 - accuracy: 0.7388
# Epoch 139/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5348 - accuracy: 0.7392
# Epoch 140/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5353 - accuracy: 0.7373
# Epoch 141/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7386
# Epoch 142/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7395
# Epoch 143/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5348 - accuracy: 0.7388
# Epoch 144/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5348 - accuracy: 0.7377
# Epoch 145/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5351 - accuracy: 0.7401
# Epoch 146/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5340 - accuracy: 0.7386
# Epoch 147/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5344 - accuracy: 0.7396
# Epoch 148/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5350 - accuracy: 0.7382
# Epoch 149/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7394
# Epoch 150/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5341 - accuracy: 0.7402
# Epoch 151/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7386
# Epoch 152/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5341 - accuracy: 0.7401
# Epoch 153/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5345 - accuracy: 0.7394
# Epoch 154/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7395
# Epoch 155/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5344 - accuracy: 0.7397
# Epoch 156/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5343 - accuracy: 0.7382
# Epoch 157/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5350 - accuracy: 0.7389
# Epoch 158/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7396
# Epoch 159/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5344 - accuracy: 0.7394
# Epoch 160/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7383
# Epoch 161/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5343 - accuracy: 0.7382
# Epoch 162/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5342 - accuracy: 0.7381
# Epoch 163/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5348 - accuracy: 0.7380
# Epoch 164/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5345 - accuracy: 0.7398
# Epoch 165/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7402
# Epoch 166/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5345 - accuracy: 0.7381
# Epoch 167/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5519 - accuracy: 0.7379
# Epoch 168/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5343 - accuracy: 0.7379
# Epoch 169/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7399
# Epoch 170/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5340 - accuracy: 0.7394
# Epoch 171/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5335 - accuracy: 0.7381
# Epoch 172/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7385
# Epoch 173/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7378
# Epoch 174/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7400
# Epoch 175/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5335 - accuracy: 0.7398
# Epoch 176/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5341 - accuracy: 0.7388
# Epoch 177/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5343 - accuracy: 0.7384
# Epoch 178/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7393
# Epoch 179/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5337 - accuracy: 0.7386
# Epoch 180/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7410
# Epoch 181/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7398
# Epoch 182/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5342 - accuracy: 0.7391
# Epoch 183/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7382
# Epoch 184/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5343 - accuracy: 0.7395
# Epoch 185/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7406
# Epoch 186/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5337 - accuracy: 0.7392
# Epoch 187/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7376
# Epoch 188/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5335 - accuracy: 0.7390
# Epoch 189/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5335 - accuracy: 0.7391
# Epoch 190/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7391
# Epoch 191/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7397
# Epoch 192/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5344 - accuracy: 0.7404
# Epoch 193/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5331 - accuracy: 0.7396
# Epoch 194/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5337 - accuracy: 0.7390
# Epoch 195/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5335 - accuracy: 0.7397
# Epoch 196/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7390
# Epoch 197/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5333 - accuracy: 0.7400
# Epoch 198/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5337 - accuracy: 0.7376
# Epoch 199/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5337 - accuracy: 0.7394
# Epoch 200/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5331 - accuracy: 0.7382
# Epoch 201/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7400
# Epoch 202/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7401
# Epoch 203/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7385
# Epoch 204/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5333 - accuracy: 0.7393
# Epoch 205/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7407
# Epoch 206/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5332 - accuracy: 0.7385
# Epoch 207/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5329 - accuracy: 0.7392
# Epoch 208/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5330 - accuracy: 0.7395
# Epoch 209/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5335 - accuracy: 0.7397
# Epoch 210/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7401
# Epoch 211/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5329 - accuracy: 0.7395
# Epoch 212/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5332 - accuracy: 0.7407
# Epoch 213/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5392 - accuracy: 0.7388
# Epoch 214/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7408
# Epoch 215/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5459 - accuracy: 0.7404
# Epoch 216/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5328 - accuracy: 0.7411
# Epoch 217/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5320 - accuracy: 0.7410
# Epoch 218/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7397
# Epoch 219/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7398
# Epoch 220/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5320 - accuracy: 0.7401
# Epoch 221/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5326 - accuracy: 0.7402
# Epoch 222/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7407
# Epoch 223/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7395
# Epoch 224/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5330 - accuracy: 0.7386
# Epoch 225/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5329 - accuracy: 0.7394
# Epoch 226/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5326 - accuracy: 0.7406
# Epoch 227/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7406
# Epoch 228/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5331 - accuracy: 0.7409
# Epoch 229/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5326 - accuracy: 0.7391
# Epoch 230/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7395
# Epoch 231/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7389
# Epoch 232/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7406
# Epoch 233/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7393
# Epoch 234/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5329 - accuracy: 0.7401
# Epoch 235/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5335 - accuracy: 0.7405
# Epoch 236/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5331 - accuracy: 0.7403
# Epoch 237/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7399
# Epoch 238/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7397
# Epoch 239/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5326 - accuracy: 0.7396
# Epoch 240/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7393
# Epoch 241/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7402
# Epoch 242/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7404
# Epoch 243/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7405
# Epoch 244/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5330 - accuracy: 0.7402
# Epoch 245/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5332 - accuracy: 0.7409
# Epoch 246/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7410
# Epoch 247/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5331 - accuracy: 0.7392
# Epoch 248/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7401
# Epoch 249/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7397
# Epoch 250/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7390
# Epoch 251/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7402
# Epoch 252/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7401
# Epoch 253/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5326 - accuracy: 0.7423
# Epoch 254/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5332 - accuracy: 0.7397
# Epoch 255/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7410
# Epoch 256/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7398
# Epoch 257/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7408
# Epoch 258/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7393
# Epoch 259/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7399
# Epoch 260/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5318 - accuracy: 0.7423
# Epoch 261/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7409
# Epoch 262/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7406
# Epoch 263/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5314 - accuracy: 0.7405
# Epoch 264/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7409
# Epoch 265/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5318 - accuracy: 0.7420
# Epoch 266/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7399
# Epoch 267/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5318 - accuracy: 0.7416
# Epoch 268/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7412
# Epoch 269/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5329 - accuracy: 0.7390
# Epoch 270/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7403
# Epoch 271/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5316 - accuracy: 0.7404
# Epoch 272/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5329 - accuracy: 0.7392
# Epoch 273/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7401
# Epoch 274/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5319 - accuracy: 0.7412
# Epoch 275/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5321 - accuracy: 0.7399
# Epoch 276/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7394
# Epoch 277/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7400
# Epoch 278/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7405
# Epoch 279/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7395
# Epoch 280/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5317 - accuracy: 0.7417
# Epoch 281/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7404
# Epoch 282/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7412
# Epoch 283/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7410
# Epoch 284/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5326 - accuracy: 0.7412
# Epoch 285/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7407
# Epoch 286/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7405
# Epoch 287/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7409
# Epoch 288/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5319 - accuracy: 0.7415
# Epoch 289/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7400
# Epoch 290/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5320 - accuracy: 0.7399
# Epoch 291/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7398
# Epoch 292/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5320 - accuracy: 0.7389
# Epoch 293/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7396
# Epoch 294/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5320 - accuracy: 0.7400
# Epoch 295/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7409
# Epoch 296/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5321 - accuracy: 0.7406
# Epoch 297/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5307 - accuracy: 0.7410
# Epoch 298/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5321 - accuracy: 0.7383
# Epoch 299/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5321 - accuracy: 0.7400
# Epoch 300/300
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7408

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5596 - accuracy: 0.7294 - 348ms/epoch - 1ms/step
# Loss: 0.559593141078949, Accuracy: 0.7294460535049438

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
import h5py
import numpy as np

nn.save('Alphabet_SoupCharity_Optimization.h5')
